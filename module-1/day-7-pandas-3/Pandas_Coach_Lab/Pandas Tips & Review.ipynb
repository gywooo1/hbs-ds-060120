# %% [markdown]
# # Pandas Tips & Review
# ### As a data scientist, you will be utilizing the pandas library in various ways to solve some of the world's most pressing issues
#
#
# ### Here are some useful pandas methods to manipulate dataframes to do and show us whatever we want!

# %% [markdown]
# ![Alt Text](https://media.giphy.com/media/FYnYcQoFmlPeU/giphy.gif)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Let's use the merge function from pandas to combine two dataframes together

# %%
df1 = pd.read_csv('heart.csv')
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df2 = pd.DataFrame(np.random.randint(0,100,size=(1025,3)), columns=['B','C','D'])
df2.head()
# Out:
#     B   C   D
# 0  61  17  33
# 1  33  66  23
# 2  86  45  36
# 3  18  40  53
# 4   3  45  77

# %% [markdown]
# Answer Below

# %%
df3 = pd.merge(df1,df2, on=df2.index)

# %%
df3.head()
# Out:
#    key_0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      0   52    1   0       125   212    0        1      168      0      1.0
# 1      1   53    1   0       140   203    1        0      155      1      3.1
# 2      2   70    1   0       145   174    0        1      125      1      2.6
# 3      3   61    1   0       148   203    0        1      161      0      0.0
# 4      4   62    0   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target   B   C   D
# 0      2   2     3       0  61  17  33
# 1      0   0     3       0  33  66  23
# 2      0   0     3       0  86  45  36
# 3      2   1     3       0  18  40  53
# 4      1   3     2       0   3  45  77

# %% [markdown]
# #### What if we wanted to simply add on a few relevant columns with data to our dataframe? (Hint: Use Concat)

# %%
lab_df = pd.DataFrame(np.random.randint(0,100,size=(1025,3)), columns=['Chemical_A','Chemical_B','Chemical_C'])

# %%
lab_df.head()
# Out:
#    Chemical_A  Chemical_B  Chemical_C
# 0          55          79          68
# 1          35          35          89
# 2          31          90          78
# 3          77           0          70
# 4          10          77           2

# %% [markdown]
# Answer Below

# %%
concated_df = pd.concat([df2,lab_df],axis=1)

# %%
concated_df.head()
# Out:
#     B   C   D  Chemical_A  Chemical_B  Chemical_C
# 0  61  17  33          55          79          68
# 1  33  66  23          35          35          89
# 2  86  45  36          31          90          78
# 3  18  40  53          77           0          70
# 4   3  45  77          10          77           2

# %% [markdown]
# ### So what exactly does the join method do? Use the join method utilizing the 'left join'

# %%
df1.join(df2, on=df1.index, how='left')
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# 8      46    1   0       120   249    0        0      144      0      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 10     71    0   0       112   149    0        1      125      0      1.6
# 11     43    0   0       132   341    1        0      136      1      3.0
# 12     34    0   1       118   210    0        1      192      0      0.7
# 13     51    1   0       140   298    0        1      122      1      4.2
# 14     52    1   0       128   204    1        1      156      1      1.0
# 15     34    0   1       118   210    0        1      192      0      0.7
# 16     51    0   2       140   308    0        0      142      0      1.5
# 17     54    1   0       124   266    0        0      109      1      2.2
# 23        2   0     2       1  51  59  21
# 24        1   0     2       1  24  92  73
# 25        1   0     3       0   7  74  31
# 26        2   0     2       1  31  72  76
# 27        2   2     2       0  26  34   6
# 28        1   1     1       0  88  93  83
# 29        1   0     2       0  67  49  99
# ...     ...  ..   ...     ...  ..  ..  ..
# 995       2   0     3       1  76  63  22
# 996       1   2     3       0  20   8  66
# 997       1   1     3       0  86  46  18
# 998       1   0     1       0  23  67  61
# 999       1   2     3       0  61  13   5
# 1000      1   2     1       0  99  80  44
# 1001      2   0     2       1  18  43  98
# 1002      2   1     2       0  74  52  71
# 1003      2   3     3       1  40  39  69
# 1004      2   1     2       1  39   4  36
# 1005      1   1     3       0  55  79  75
# 1006      2   0     2       1  40  60  89
# 1007      1   0     3       1  62  98   5
# 1008      2   0     2       1  61  20  28
# 1009      2   0     3       0   4  82  30
# 1010      2   0     3       0  27  19   6
# 1011      2   0     2       1  13   8  15
# 1012      0   0     3       0  24  95   3
# 1013      0   3     1       0   6  36   0
# 1014      1   0     2       1  88  84  72
# 1015      1   3     3       0  87  60  83
# 1016      1   1     2       0   0  81  99
# 1017      1   2     3       0  53  96  29
# 1018      2   0     3       0  26  19  68
# 1019      2   0     2       1   0  72  23
# 1020      2   0     2       1  28  79  68
# 1021      1   1     3       0  63  31  33
# 1022      1   1     2       0  42  43  93
# 1023      2   0     2       1  10  99  54
# 1024      1   1     3       0   8  26   9
#
# [1025 rows x 17 columns]

# %% [markdown]
# Answer Below

# %%
joined_df = df1.join(df2, on=df1.index,how='left')

# %%
joined_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target   B   C   D
# 0   2     3       0  61  17  33
# 1   0     3       0  33  66  23
# 2   0     3       0  86  45  36
# 3   1     3       0  18  40  53
# 4   3     2       0   3  45  77

# %% [markdown]
# ## Now let's talk about .loc vs .iloc

# %% [markdown]
# The Pandas loc indexer can be used with DataFrames for two different use cases:
#
# a.) Selecting rows by label/index
# b.) Selecting rows with a boolean / conditional lookup

# %% [markdown]
# a.) Selecting rows by label/index

# %%
# Select rows with index values '0' through '100', with all columns between 'age' and 'chol'
joined_df.loc[0:100, 'age':'chol'].head()
# Out:
#    age  sex  cp  trestbps  chol
# 0   52    1   0       125   212
# 1   53    1   0       140   203
# 2   70    1   0       145   174
# 3   61    1   0       148   203
# 4   62    0   0       138   294

# %% [markdown]
# >Notice below .loc[487] does not grab row 487, but rather the index of 487

# %%
joined_df.loc[487]
# Out:
# age          65.0
# sex           1.0
# cp            0.0
# trestbps    135.0
# chol        254.0
# fbs           0.0
# restecg       0.0
# thalach     127.0
# exang         0.0
# oldpeak       2.8
# slope         1.0
# ca            1.0
# thal          3.0
# target        0.0
# B            16.0
# C            63.0
# D            80.0
# Name: 487, dtype: float64

# %% [markdown]
# b.) Selecting rows with a boolean / conditional lookup

# %%
# select rows with indexes between 100 and 200, and just return 'age' and 'cp' columns
joined_df.loc[(joined_df.index > 100) & (joined_df.index <= 200), ['age', 'cp']].head()
# Out:
#      age  cp
# 101   57   2
# 102   54   1
# 103   47   2
# 104   52   3
# 105   47   0

# %% [markdown]
# The iloc indexer for Pandas Dataframe is used for integer-location based indexing / selection by position.

# %% [markdown]
# ##### Use .iloc to grab specific rows

# %% [markdown]
# First 4 rows

# %%
joined_df.iloc[0:4]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
#
#    ca  thal  target   B   C   D
# 0   2     3       0  61  17  33
# 1   0     3       0  33  66  23
# 2   0     3       0  86  45  36
# 3   1     3       0  18  40  53

# %% [markdown]
# First 3 columns

# %%
joined_df.iloc[:,0:3]
# Out:
#       age  sex  cp
# 0      52    1   0
# 1      53    1   0
# 2      70    1   0
# 3      61    1   0
# 4      62    0   0
# 5      58    0   0
# 6      58    1   0
# 7      55    1   0
# 8      46    1   0
# 9      54    1   0
# 10     71    0   0
# 11     43    0   0
# 12     34    0   1
# 13     51    1   0
# 14     52    1   0
# 15     34    0   1
# 16     51    0   2
# 17     54    1   0
# 18     50    0   1
# 19     58    1   2
# 20     60    1   2
# 21     67    0   0
# 22     45    1   0
# 23     63    0   2
# 24     42    0   2
# 25     61    0   0
# 26     44    1   2
# 27     58    0   1
# 28     56    1   2
# 29     55    0   0
# ...   ...  ...  ..
# 995    44    1   1
# 996    56    0   0
# 997    54    1   0
# 998    42    1   0
# 999    67    1   0
# 1000   64    1   0
# 1001   42    1   0
# 1002   66    1   0
# 1003   52    1   0
# 1004   51    0   2
# 1005   55    0   0
# 1006   58    1   2
# 1007   56    1   3
# 1008   42    1   1
# 1009   40    1   0
# 1010   51    1   0
# 1011   45    1   1
# 1012   48    1   1
# 1013   58    1   0
# 1014   44    0   2
# 1015   58    1   0
# 1016   65    1   3
# 1017   53    1   0
# 1018   41    1   0
# 1019   47    1   0
# 1020   59    1   1
# 1021   60    1   0
# 1022   47    1   0
# 1023   50    0   0
# 1024   54    1   0
#
# [1025 rows x 3 columns]

# %% [markdown]
# Or grab rows (0,3,6,24) from columns (0,5,6)

# %%
joined_df.iloc[[0,3,6,24], [0,5,6]]
# Out:
#     age  fbs  restecg
# 0    52    0        1
# 3    61    0        1
# 6    58    0        2
# 24   42    0        1

# %% [markdown]
# # Ways to utilize lambda functions
# #### .map(), .apply(), .applymap()

# %% [markdown]
# The map() method only works on pandas series

# %% [markdown]
# The apply () method works on panda series and data frames

# %% [markdown]
# The applymap() method works on the entire pandas data frame where the input function is applied to every element individually. In other words, applymap() is appy() + map()!

# %% [markdown]
# Summing up, apply works on a row / column basis of a DataFrame, applymap works element-wise on a DataFrame, and map works element-wise on a Series.

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
new_df = df.age.map(lambda x: x * 10)

# %%
super_df = df.age.apply(lambda x: x * 10)

# %% [markdown]
# #### How else could we manipulate the 'age' column?

# %% [markdown]
# Do these two dataframes equal the same thing?

# %%
(new_df == super_df).value_counts()
# Out:
# True    1025
# Name: age, dtype: int64

# %%
apply_df = df.applymap(lambda x: x*10)

# %%
apply_df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     520   10   0      1250  2120    0       10     1680      0     10.0
# 1     530   10   0      1400  2030   10        0     1550     10     31.0
# 2     700   10   0      1450  1740    0       10     1250     10     26.0
# 3     610   10   0      1480  2030    0       10     1610      0      0.0
# 4     620    0   0      1380  2940   10       10     1060      0     19.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020  590   10  10      1400  2210    0       10     1640     10      0.0
# 1021  600   10   0      1250  2580    0        0     1410     10     28.0
# 1022  470   10   0      1100  2750    0        0     1180     10     10.0
# 1023  500    0   0      1100  2540    0        0     1590      0      0.0
# 1024  540   10   0      1200  1880    0       10     1130      0     14.0
#
#       slope  ca  thal  target
# 0        20  20    30       0
# 1         0   0    30       0
# 2         0   0    30       0
# 3        20  10    30       0
# 4        10  30    20       0
# ...     ...  ..   ...     ...
# 1020     20   0    20      10
# 1021     10  10    30       0
# 1022     10  10    20       0
# 1023     20   0    20      10
# 1024     10  10    30       0
#
# [1025 rows x 14 columns]

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading https://files.pythonhosted.org/packages/1c/9d/39cc13537ba25a7819bd566d0b0cddfa5570579c194756ac3aff57256dcd/Faker-4.1.0-py3-none-any.whl (1.0MB)
#     100% |████████████████████████████████| 1.0MB 9.2MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.4 in /anaconda3/lib/python3.7/site-packages (from faker) (2.7.5)
# Collecting text-unidecode==1.3 (from faker)
#   Downloading https://files.pythonhosted.org/packages/a6/a5/c0b6468d3824fe3fde30dbb5e1f687b291608f9473681bbf7dabbf5a87d7/text_unidecode-1.3-py2.py3-none-any.whl (78kB)
#     100% |████████████████████████████████| 81kB 12.7MB/s ta 0:00:01
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.4->faker) (1.12.0)
# Installing collected packages: text-unidecode, faker
# Successfully installed faker-4.1.0 text-unidecode-1.3

# %%
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Emily Walters'

# %% [markdown]
# Let's generate a column of names

# %%
df['name'] = [fake.name() for x in range(1025)]
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target              name
# 1020      2   0     2       1       James Dixon
# 1021      1   1     3       0    Jennifer Ayala
# 1022      1   1     2       0     Jillian Casey
# 1023      2   0     2       1  Jonathan Miranda
# 1024      1   1     3       0      Amber Benson

# %%
df.name = df.name.map(lambda x: x.replace(" ",'_'))

# %% [markdown]
# ## BONUS:
# ##### Can you grab the row with info on Brent Jones?

# %%
# Out:
# ['James_Dixon']

# %%
brent_jones = df.loc[df.name == 'Brent_Jones']
brent_jones
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target, name]
# Index: []

# %% [markdown]
# Answer Below

# %%
brent_jones = df.loc[df['name'] == 'Brent_Jones']

# %%
brent_jones
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target, name]
# Index: []
