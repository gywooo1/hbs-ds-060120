# %% [markdown]
# # Module 1 - Reshaping Data with Pandas
# ## Pandas Part 3

# %%
import pandas as pd
uci = pd.read_csv('data/heart.csv')

# %%
uci.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## 3. Methods for Re-Organizing DataFrames
# #### `.groupby()`

# %% [markdown]
# Those of you familiar with SQL have probably used the GROUP BY command. Pandas has this, too.
#
# The `.groupby()` method is especially useful for aggregate functions applied to the data grouped in particular ways.

# %%
gb = uci.groupby('sex')

# %% [markdown]
# #### `.groups` and `.get_group()`

# %%
uci.groupby('sex').groups
# Out:
# {0: Int64Index([  2,   4,   6,  11,  14,  15,  16,  17,  19,  25,  28,  30,  35,
#               36,  38,  39,  40,  43,  48,  49,  50,  53,  54,  59,  60,  65,
#               67,  69,  74,  75,  82,  84,  85,  88,  89,  93,  94,  96, 102,
#              105, 107, 108, 109, 110, 112, 115, 118, 119, 120, 122, 123, 124,
#              125, 127, 128, 129, 130, 131, 134, 135, 136, 140, 142, 143, 144,
#              146, 147, 151, 153, 154, 155, 161, 167, 181, 182, 190, 204, 207,
#              213, 215, 216, 220, 223, 241, 246, 252, 258, 260, 263, 266, 278,
#              289, 292, 296, 298, 302],
#             dtype='int64'),
#  1: Int64Index([  0,   1,   3,   5,   7,   8,   9,  10,  12,  13,
#              ...
#              288, 290, 291, 293, 294, 295, 297, 299, 300, 301],
#             dtype='int64', length=207)}

# %%
uci.groupby('sex').get_group(0).head()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 2    41    0   1       130   204    0        0      172      0      1.4
# 4    57    0   0       120   354    0        1      163      1      0.6
# 6    56    0   1       140   294    0        0      153      0      1.3
# 11   48    0   2       130   275    0        1      139      0      0.2
# 14   58    0   3       150   283    1        0      162      0      1.0
#
#     slope  ca  thal  target
# 2       2   0     2       1
# 4       2   0     2       1
# 6       1   0     2       1
# 11      2   0     2       1
# 14      2   0     2       1

# %% [markdown]
# ### Aggregating

# %%
uci.groupby('sex').mean()
# Out:
#            age        cp    trestbps        chol      fbs   restecg  \
# sex
# 0    55.677083  1.041667  133.083333  261.302083  0.12500  0.572917
# 1    53.758454  0.932367  130.946860  239.289855  0.15942  0.507246
#
#         thalach     exang   oldpeak     slope        ca      thal    target
# sex
# 0    151.125000  0.229167  0.876042  1.427083  0.552083  2.125000  0.750000
# 1    148.961353  0.371981  1.115459  1.386473  0.811594  2.400966  0.449275

# %% [markdown]
# Exercise: Tell me the average cholesterol level for those with heart disease.

# %%
# Your code here!
uci.groupby('target').mean().loc[1, 'chol']
# Out:
# 242.23030303030302

# %%
uci.groupby('target').get_group(1).mean()['chol']
# Out:
# 242.23030303030302

# %%
uci.groupby('cp').std().loc[3,'slope']
# Out:
# 0.6887004431501819

# %%
uci.groupby(['sex','cp']).quantile(0.3)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:4315: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   stacked_values = np.vstack(map(np.asarray, values))
# 0.3      age   ca   chol  exang  fbs  oldpeak  restecg  slope  target  thal  \
# sex cp
# 0   0   55.4  0.0  234.8    0.0  0.0     0.24      0.0    1.0     0.0   2.0
#     1   45.1  0.0  212.4    0.0  0.0     0.00      0.0    1.1     1.0   2.0
#     2   50.2  0.0  214.2    0.0  0.0     0.00      0.0    1.0     1.0   2.0
#     3   59.8  0.0  237.7    0.0  0.0     0.99      0.9    1.8     1.0   2.0
# 1   0   51.9  0.0  212.0    0.0  0.0     0.40      0.0    1.0     0.0   2.0
#     1   45.3  0.0  220.0    0.0  0.0     0.00      0.0    2.0     1.0   2.0
#     2   47.3  0.0  215.2    0.0  0.0     0.00      0.0    1.0     0.0   2.0
#     3   51.4  0.0  211.8    0.0  0.0     0.68      0.0    1.0     0.0   2.0
#
# 0.3     thalach  trestbps
# sex cp
# 0   0     136.0     130.0
#     1     161.1     120.6
#     2     149.0     120.0
#     3     147.3     149.0
# 1   0     125.9     120.0
#     1     156.0     120.0
#     2     150.0     125.0
#     3     145.0     122.0

# %% [markdown]
# ### Apply to Animal Shelter Data

# %%
animal_outcomes = pd.read_csv('https://data.austintexas.gov/api/views/wter-evkm/rows.csv?accessType=DOWNLOAD')

# %%
animal_outcomes.head(4)
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
# 2         Dog     Intact Male       11 months               Basenji Mix
# 3         Cat   Intact Female         4 weeks    Domestic Shorthair Mix
#
#          Color
# 0     Tricolor
# 1  White/Liver
# 2  Sable/White
# 3       Calico

# %%
animal_outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117738 entries, 0 to 117737
# Data columns (total 12 columns):
# Animal ID           117738 non-null object
# Name                80680 non-null object
# DateTime            117738 non-null object
# MonthYear           117738 non-null object
# Found Location      117738 non-null object
# Intake Type         117738 non-null object
# Intake Condition    117738 non-null object
# Animal Type         117738 non-null object
# Sex upon Intake     117737 non-null object
# Age upon Intake     117738 non-null object
# Breed               117738 non-null object
# Color               117738 non-null object
# dtypes: object(12)
# memory usage: 10.8+ MB

# %% [markdown]
# #### Task 1
# - Use a groupby to show the average age of the different kinds of animal types.
# - What about by animal types **and** gender?

# %%
animal_outcomes['date of birth'] = pd.to_datetime(animal_outcomes['DateTime'])

# %%
animal_outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117738 entries, 0 to 117737
# Data columns (total 13 columns):
# Animal ID           117738 non-null object
# Name                80680 non-null object
# DateTime            117738 non-null object
# MonthYear           117738 non-null object
# Found Location      117738 non-null object
# Intake Type         117738 non-null object
# Intake Condition    117738 non-null object
# Animal Type         117738 non-null object
# Sex upon Intake     117737 non-null object
# Age upon Intake     117738 non-null object
# Breed               117738 non-null object
# Color               117738 non-null object
# date of birth       117738 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 11.7+ MB

# %%
import datetime
def calculate_age(val):
    return round((datetime.datetime.now() - val).days / 365, 2)

# %%
import datetime
animal_outcomes['age'] = animal_outcomes['date of birth'].map(lambda x: round((datetime.datetime.now()-x).days/365,2))

# %%
animal_outcomes.groupby('Animal Type').mean()['age']
# Out:
# Animal Type
# Bird         3.079434
# Cat          3.425571
# Dog          3.431756
# Livestock    2.779524
# Other        3.538703
# Name: age, dtype: float64

# %%
animal_outcomes.groupby(['Animal Type','Sex upon Intake']).mean()['age']
# Out:
# Animal Type  Sex upon Intake
# Bird         Intact Female      2.679595
#              Intact Male        3.533660
#              Unknown            2.955109
# Cat          Intact Female      3.420378
#              Intact Male        3.442003
#              Neutered Male      3.377521
#              Spayed Female      3.439932
#              Unknown            3.425204
# Dog          Intact Female      3.361919
#              Intact Male        3.392427
#              Neutered Male      3.488660
#              Spayed Female      3.588490
#              Unknown            2.785632
# Livestock    Intact Female      2.782500
#              Intact Male        3.430000
#              Neutered Male      6.280000
#              Unknown            2.013750
# Other        Intact Female      3.293537
#              Intact Male        3.133803
#              Neutered Male      2.956716
#              Spayed Female      3.068704
#              Unknown            3.607722
# Name: age, dtype: float64

# %% [markdown]
# #### Task 2:
# - Create new columns `year` and `month` by using a lambda function x.year on date
# - Use `groupby` and `.size()` to tell me how many animals are adopted by month

# %%
# Your code here
animal_outcomes['year'] = pd.to_datetime(animal_outcomes.DateTime).map(lambda x: x.year)

# %%
animal_outcomes['month'] = pd.to_datetime(animal_outcomes.DateTime).map(lambda x: x.month)

# %%
animal_outcomes.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color       date of birth  \
# 0                             Beagle Mix     Tricolor 2019-01-03 16:19:00
# 1               English Springer Spaniel  White/Liver 2015-07-05 12:59:00
# 2                            Basenji Mix  Sable/White 2016-04-14 18:43:00
# 3                 Domestic Shorthair Mix       Calico 2013-10-21 07:59:00
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray 2014-06-29 10:38:00
#
#     age  year  month
# 0  1.43  2019      1
# 1  4.93  2015      7
# 2  4.15  2016      4
# 3  6.64  2013     10
# 4  5.95  2014      6

# %%
animal_outcomes.groupby('month').size()
# Out:
# month
# 1      8479
# 2      8027
# 3      9318
# 4      9442
# 5     12337
# 6     11464
# 7     10203
# 8      9752
# 9      9972
# 10    10975
# 11     9303
# 12     8466
# dtype: int64

# %% [markdown]
# ## 4. Reshaping a DataFrame
#
# ### `.pivot()`

# %% [markdown]
# Those of you familiar with Excel have probably used Pivot Tables. Pandas has a similar functionality.

# %%
uci.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
uci.pivot(values='sex', columns='target').head()
# Out:
# target   0    1
# 0      NaN  1.0
# 1      NaN  1.0
# 2      NaN  0.0
# 3      NaN  1.0
# 4      NaN  0.0

# %%
uci.pivot(values='age',columns='target').head()
# Out:
# target   0     1
# 0      NaN  63.0
# 1      NaN  37.0
# 2      NaN  41.0
# 3      NaN  56.0
# 4      NaN  57.0

# %%
uci.pivot(values=['cp','sex'], columns='target').head()
# Out:
#         cp      sex
# target   0    1   0    1
# 0      NaN  3.0 NaN  1.0
# 1      NaN  2.0 NaN  1.0
# 2      NaN  1.0 NaN  0.0
# 3      NaN  1.0 NaN  1.0
# 4      NaN  0.0 NaN  0.0

# %% [markdown]
# ### Methods for Combining DataFrames: `.join()`, `.merge()`, `.concat()`, `.melt()`

# %% [markdown]
# ### `.join()`

# %%
toy1 = pd.DataFrame([[63, 142], [33, 47]], columns=['age', 'HP'])
toy2 = pd.DataFrame([[63, 100], [33, 200]], columns=['age', 'HP'])

# %%
toy1
# Out:
#    age   HP
# 0   63  142
# 1   33   47

# %%
toy2
# Out:
#    age   HP
# 0   63  100
# 1   33  200

# %%
toy1.join(toy2.set_index('age'),
         on = 'age',
         lsuffix= '_A',
         rsuffix= '_B')
# Out:
#    age  HP_A  HP_B
# 0   63   142   100
# 1   33    47   200

# %%
toy1.join(toy2.set_index('age'),
          on='age',
          lsuffix='_A',
          rsuffix='_B').head()
# Out:
#    age  HP_A  HP_B
# 0   63   142   100
# 1   33    47   200

# %% [markdown]
# ### `.merge()`

# %%
ds_chars = pd.read_csv('data/ds_chars.csv', index_col=0)
ds_chars
# Out:
#      name   HP home_state
# 0    greg  200         WA
# 1   miles  200         WA
# 2    alan  170         TX
# 3  alison  300         DC
# 4  rachel  200         TX

# %%
states = pd.read_csv('data/states.csv', index_col=0)
states
# Out:
#   state   nickname     capital
# 0    WA  evergreen     Olympia
# 1    TX      alamo      Austin
# 2    DC   district  Washington
# 3    OH    buckeye    Columbus
# 4    OR     beaver       Salem

# %%
ds_chars.join(states.set_index('state'),
             on = 'home_state')
# Out:
#      name   HP home_state   nickname     capital
# 0    greg  200         WA  evergreen     Olympia
# 1   miles  200         WA  evergreen     Olympia
# 2    alan  170         TX      alamo      Austin
# 3  alison  300         DC   district  Washington
# 4  rachel  200         TX      alamo      Austin

# %%
ds_chars.merge(states,
              left_on='home_state',
              right_on='state',
              how = 'inner')
# Out:
#      name   HP home_state state   nickname     capital
# 0    greg  200         WA    WA  evergreen     Olympia
# 1   miles  200         WA    WA  evergreen     Olympia
# 2    alan  170         TX    TX      alamo      Austin
# 3  rachel  200         TX    TX      alamo      Austin
# 4  alison  300         DC    DC   district  Washington

# %%
ds_chars.merge(states,
               left_on='home_state',
               right_on='state',
               how='inner')
# Out:
#      name   HP home_state state   nickname     capital
# 0    greg  200         WA    WA  evergreen     Olympia
# 1   miles  200         WA    WA  evergreen     Olympia
# 2    alan  170         TX    TX      alamo      Austin
# 3  rachel  200         TX    TX      alamo      Austin
# 4  alison  300         DC    DC   district  Washington

# %% [markdown]
# ### `pd.concat()`

# %%
pd.concat([ds_chars, states], sort=False)
# Out:
#      name     HP home_state state   nickname     capital
# 0    greg  200.0         WA   NaN        NaN         NaN
# 1   miles  200.0         WA   NaN        NaN         NaN
# 2    alan  170.0         TX   NaN        NaN         NaN
# 3  alison  300.0         DC   NaN        NaN         NaN
# 4  rachel  200.0         TX   NaN        NaN         NaN
# 0     NaN    NaN        NaN    WA  evergreen     Olympia
# 1     NaN    NaN        NaN    TX      alamo      Austin
# 2     NaN    NaN        NaN    DC   district  Washington
# 3     NaN    NaN        NaN    OH    buckeye    Columbus
# 4     NaN    NaN        NaN    OR     beaver       Salem

# %% [markdown]
# ### `pd.melt()`

# %% [markdown]
# Melting removes the structure from your DataFrame and puts the data in a 'variable' and 'value' format.

# %%
ds_chars.head()
# Out:
#      name   HP home_state
# 0    greg  200         WA
# 1   miles  200         WA
# 2    alan  170         TX
# 3  alison  300         DC
# 4  rachel  200         TX

# %%
pd.melt(ds_chars,
        id_vars=['name'],
        value_vars=['HP', 'home_state'])
# Out:
#      name    variable value
# 0    greg          HP   200
# 1   miles          HP   200
# 2    alan          HP   170
# 3  alison          HP   300
# 4  rachel          HP   200
# 5    greg  home_state    WA
# 6   miles  home_state    WA
# 7    alan  home_state    TX
# 8  alison  home_state    DC
# 9  rachel  home_state    TX

# %%
pd.melt(animal_outcomes, id_vars=['Animal ID'], value_vars=['Age upon Intake']

# %% [markdown]
# ## Bringing it all together with the Animal Shelter Data
#
# Join the data from the [Austin Animal Shelter Intake dataset](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) to the outcomes dataset by Animal ID.
#
# Use the dates from each dataset to see how long animals spend in the shelter. Does it differ by time of year? By outcome?
#
# _Hints_ :
# - import and clean the intake dataset first
# - use `apply`/`applymap`/`lambda` to change the variables to their proper format in the intake data
# - rename the columns in the intake dataset *before* joining
# - create a new `days_in_shelter` column
# - Notice that some values in `days_in_shelter` are `NaN` or values < 0 (remove these rows using the "<" operator and `isna()` or `dropna()`)
# - Use `groupby` to get aggregate information about the dataset (your choice)
#
# To save your dataset:
# Use the notation `df.to_csv()` or `df.to_excel()` to write the `df` to a csv. Read more about the `to_csv()` documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html)

# %%
#code here
import pandas as pd
animal_intakes = pd.read_csv('https://data.austintexas.gov/api/views/wter-evkm/rows.csv?accessType=DOWNLOAD')
animal_outcomes = pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')

# %%
animal_outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118038 entries, 0 to 118037
# Data columns (total 12 columns):
# Animal ID           118038 non-null object
# Name                81057 non-null object
# DateTime            118038 non-null object
# MonthYear           118038 non-null object
# Date of Birth       118038 non-null object
# Outcome Type        118030 non-null object
# Outcome Subtype     53660 non-null object
# Animal Type         118038 non-null object
# Sex upon Outcome    118034 non-null object
# Age upon Outcome    117991 non-null object
# Breed               118038 non-null object
# Color               118038 non-null object
# dtypes: object(12)
# memory usage: 10.8+ MB

# %%
animal_intakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117746 entries, 0 to 117745
# Data columns (total 12 columns):
# Animal ID           117746 non-null object
# Name                80687 non-null object
# DateTime            117746 non-null object
# MonthYear           117746 non-null object
# Found Location      117746 non-null object
# Intake Type         117746 non-null object
# Intake Condition    117746 non-null object
# Animal Type         117746 non-null object
# Sex upon Intake     117745 non-null object
# Age upon Intake     117746 non-null object
# Breed               117746 non-null object
# Color               117746 non-null object
# dtypes: object(12)
# memory usage: 10.8+ MB

# %%
animal_intakes.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
animal_outcomes.head()
# Out:
#   Animal ID        Name                DateTime               MonthYear  \
# 0   A794011       Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1   A776359       Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2   A720371       Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 3   A674754         NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
# 4   A689724  *Donatello  10/18/2014 06:52:00 PM  10/18/2014 06:52:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/02/2017    Rto-Adopt             NaN         Cat    Neutered Male
# 1    07/12/2017     Adoption             NaN         Dog    Neutered Male
# 2    10/08/2015     Adoption             NaN         Dog    Neutered Male
# 3    03/12/2014     Transfer         Partner         Cat      Intact Male
# 4    08/01/2014     Adoption             NaN         Cat    Neutered Male
#
#   Age upon Outcome                               Breed              Color
# 0          2 years              Domestic Shorthair Mix  Brown Tabby/White
# 1           1 year             Chihuahua Shorthair Mix        White/Brown
# 2         4 months  Anatol Shepherd/Labrador Retriever               Buff
# 3           6 days              Domestic Shorthair Mix       Orange Tabby
# 4         2 months              Domestic Shorthair Mix              Black

# %%
animal_intakes.columns = animal_intakes.columns.map(lambda x: x.lower().replace(' ','_'))

# %%
animal_outcomes.columns = animal_outcomes.columns.map(lambda x: x.lower().replace(' ','_'))

# %%
animal_intakes['datetime'] = pd.to_datetime(animal_intakes.datetime)
animal_outcomes['datetime'] = pd.to_datetime(animal_outcomes.datetime)

# %%
joined_table = animal_intakes.join(animal_outcomes.set_index('animal_id'),
                   on = 'animal_id',
                   lsuffix= '_intakes',
                   rsuffix= '_outcomes')

# %%
joined_table = joined_table.dropna(subset=['datetime_outcomes'])

# %%
joined_table['days_in_shelter'] = joined_table.datetime_outcomes - joined_table.datetime_intakes
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
joined_table.loc[joined_table.days_in_shelter < pd.Timedelta(0)]
# Out:
#        animal_id  name_intakes    datetime_intakes       monthyear_intakes  \
# 8        A774147           NaN 2018-06-11 07:45:00  06/11/2018 07:45:00 AM
# 9        A731435        *Casey 2016-08-08 17:52:00  08/08/2016 05:52:00 PM
# 15       A657188         Tommy 2013-11-10 17:19:00  11/10/2013 05:19:00 PM
# 21       A754715         Rheia 2019-07-29 17:19:00  07/29/2019 05:19:00 PM
# 21       A754715         Rheia 2019-07-29 17:19:00  07/29/2019 05:19:00 PM
# 29       A696205           Roo 2015-02-12 11:57:00  02/12/2015 11:57:00 AM
jackie 2020-06-07 09:51:00  06/07/2020 09:51:00 AM
# 117694   A588601        Jackie 2020-06-07 09:51:00  06/07/2020 09:51:00 AM
# 117694   A588601        Jackie 2020-06-07 09:51:00  06/07/2020 09:51:00 AM
# 117694   A588601        Jackie 2020-06-07 09:51:00  06/07/2020 09:51:00 AM
# 117694   A588601        Jackie 2020-06-07 09:51:00  06/07/2020 09:51:00 AM
# 117694   A588601        Jackie 2020-06-07 09:51:00  06/07/2020 09:51:00 AM
# 117705   A732172         Clyde 2018-04-26 13:48:00  04/26/2018 01:48:00 PM
# 117705   A732172         Clyde 2018-04-26 13:48:00  04/26/2018 01:48:00 PM
# 117708   A732172         Clyde 2016-11-27 15:42:00  11/27/2016 03:42:00 PM
# 117714   A812744         Kachy 2020-06-08 16:26:00  06/08/2020 04:26:00 PM
# 117715   A732172         Clyde 2020-06-08 14:47:00  06/08/2020 02:47:00 PM
# 117715   A732172         Clyde 2020-06-08 14:47:00  06/08/2020 02:47:00 PM
# 117715   A732172         Clyde 2020-06-08 14:47:00  06/08/2020 02:47:00 PM
# 117728   A811195     *Lawrence 2020-06-08 23:35:00  06/08/2020 11:35:00 PM
# 117741   A696243       Weebles 2015-04-26 11:39:00  04/26/2015 11:39:00 AM
# 117742   A696243       Weebles 2020-06-09 10:54:00  06/09/2020 10:54:00 AM
# 117742   A696243       Weebles 2020-06-09 10:54:00  06/09/2020 10:54:00 AM
#
#                                            found_location      intake_type  \
# 8                           6600 Elm Creek in Austin (TX)            Stray
# 9                                             Austin (TX)  Owner Surrender
# 15                                            Austin (TX)  Owner Surrender
# 21                                            Austin (TX)  Owner Surrender
# 21                                            Austin (TX)  Owner Surrender
# 29                                            Austin (TX)  Owner Surrender
# 32                                   Outside Jurisdiction  Owner Surrender
# 32                                   Outside Jurisdiction  Owner Surrender
# 41                    4200 Smith School Rd in Austin (TX)            Stray
# 41                    4200 Smith School Rd in Austin (TX)            Stray
# 41                    4200 Smith School Rd in Austin (TX)            Stray
# 65                                            Austin (TX)  Owner Surrender
# 65                                            Austin (TX)  Owner Surrender
# 71                                            Austin (TX)  Owner Surrender
# 73                                            Travis (TX)  Owner Surrender
# 73                                            Travis (TX)  Owner Surrender
# 74                     10195 Thistle Ridge in Austin (TX)            Stray
# 78                                            Austin (TX)  Owner Surrender
# 96                      6400 Huntleigh Way in Austin (TX)            Stray
# 100                        4715 S Congress in Austin (TX)    Public Assist
# 100                        4715 S Congress in Austin (TX)    Public Assist
# 112                           12900 Dessau in Travis (TX)            Stray
# 118                                           Austin (TX)  Owner Surrender
# 128                                  Outside Jurisdiction  Owner Surrender
# 128                                  Outside Jurisdiction  Owner Surrender
# 140     East Cesar Chavez Street And Mildred Drive in ...            Stray
# 147                                           Austin (TX)  Owner Surrender
# 154                                           Austin (TX)  Owner Surrender
# 160                                  Outside Jurisdiction  Owner Surrender
# 160                                  Outside Jurisdiction  Owner Surrender
# ...                                                   ...              ...
# 117598                                        Austin (TX)  Owner Surrender
# 117600           1414 Shore District Drive in Austin (TX)        Abandoned
# 117614                    2104 Pasadena Dr in Austin (TX)  Owner Surrender
# 117639                                        Austin (TX)  Owner Surrender
# 117651                     1201 W Live Oak in Austin (TX)            Stray
# 117656           4700 East Riverside Drive in Austin (TX)            Stray
# 117657              2400 E Cesar Chavez St in Austin (TX)            Stray
# 117672                    1602 Charlois Dr in Austin (TX)            Stray
# 117673                 5407 Sugar Maple Ct in Austin (TX)            Stray
# 117676                       6505 Burleson in Austin (TX)    Public Assist
# 117676                       6505 Burleson in Austin (TX)    Public Assist
# 117681              2601 S Pleasant Valley in Austin (TX)  Owner Surrender
# 117681              2601 S Pleasant Valley in Austin (TX)  Owner Surrender
# 117694          Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694          Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694          Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694          Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694          Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694          Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117705                  8209 Bluss Springs in Austin (TX)            Stray
# 117705                  8209 Bluss Springs in Austin (TX)            Stray
# 117708                                        Austin (TX)    Public Assist
# 117714                                        Austin (TX)    Public Assist
# 117715                                        Austin (TX)    Public Assist
# 117715                                        Austin (TX)    Public Assist
# 117715                                        Austin (TX)    Public Assist
# 117728                       8712 Manor Rd in Travis (TX)            Stray
# 117741                                        Austin (TX)  Owner Surrender
# 117742                                        Austin (TX)  Owner Surrender
# 117742                                        Austin (TX)  Owner Surrender
#
#        intake_condition animal_type_intakes sex_upon_intake age_upon_intake  \
# 8               Injured                 Cat   Intact Female         4 weeks
# 9                Normal                 Cat   Neutered Male        5 months
# 15               Normal                 Cat   Neutered Male        14 years
# 21               Normal                 Dog   Spayed Female         2 years
# 21               Normal                 Dog   Spayed Female         2 years
# 29               Normal                 Cat   Spayed Female         2 years
# 32                 Sick                 Dog   Spayed Female         3 years
# 32                 Sick                 Dog   Spayed Female         3 years
# 41               Normal                 Dog   Spayed Female         3 years
# 41               Normal                 Dog   Spayed Female         3 years
# 41               Normal                 Dog   Spayed Female         3 years
# 65               Normal                 Dog   Spayed Female         7 years
# 65               Normal                 Dog   Spayed Female         7 years
# 71               Normal                 Dog   Spayed Female          1 year
# 73               Normal                 Dog   Neutered Male          1 year
# 73               Normal                 Dog   Neutered Male          1 year
# 74               Normal                 Dog     Intact Male          1 year
# 78               Normal                 Dog   Neutered Male         4 years
# 96              Injured                 Cat   Spayed Female        9 months
# 100              Normal                 Dog   Spayed Female         2 years
# 100              Normal                 Dog   Spayed Female         2 years
# 112              Normal                 Dog   Intact Female         3 years
# 118              Normal                 Cat   Neutered Male        5 months
# 128              Normal                 Dog   Neutered Male         2 years
# 128              Normal                 Dog   Neutered Male         2 years
# 140              Normal                 Dog   Spayed Female        12 years
# 147              Normal                 Dog   Neutered Male         4 years
# 154              Normal                 Dog   Spayed Female         4 years
# 160              Normal                 Dog   Spayed Female        2 months
# 160              Normal                 Dog   Spayed Female        2 months
# ...                 ...                 ...             ...             ...
# 117598             Sick                 Dog   Neutered Male         7 years
# 117600           Normal                 Dog   Neutered Male         2 years
# 117614           Normal                 Cat   Neutered Male        2 months
# 117639           Normal                 Dog   Neutered Male          1 year
# 117651           Normal                 Dog   Neutered Male         3 years
# 117656             Sick                 Cat   Spayed Female         7 years
# 117657           Normal                 Dog   Intact Female          1 year
# 117672          Injured                 Cat   Spayed Female       11 months
# 117673          Injured                 Dog   Intact Female        13 years
# 117676           Normal                 Dog     Intact Male         2 years
# 117676           Normal                 Dog     Intact Male         2 years
# 117681          Injured                 Dog   Spayed Female         8 years
# 117681          Injured                 Dog   Spayed Female         8 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 
# 117676         ...           06/26/2019 06:48:00 PM    04/24/2018
# 117681         ...           10/23/2014 06:56:00 PM    10/22/2011
# 117681         ...           04/04/2016 05:08:00 PM    10/22/2011
# 117694         ...           12/05/2014 12:41:00 PM    11/10/2008
# 117694         ...           01/06/2020 02:00:00 PM    11/10/2008
# 117694         ...           12/13/2015 06:28:00 PM    11/10/2008
# 117694         ...           01/15/2018 12:52:00 PM    11/10/2008
# 117694         ...           07/07/2015 05:40:00 PM    11/10/2008
# 117694         ...           01/02/2016 06:35:00 PM    11/10/2008
# 117705         ...           12/07/2016 03:13:00 PM    03/04/2014
# 117705         ...           08/09/2016 04:49:00 PM    03/04/2014
# 117708         ...           08/09/2016 04:49:00 PM    03/04/2014
# 117714         ...           02/05/2020 05:25:00 PM    01/27/2017
# 117715         ...           05/07/2018 06:23:00 PM    03/04/2014
# 117715         ...           12/07/2016 03:13:00 PM    03/04/2014
# 117715         ...           08/09/2016 04:49:00 PM    03/04/2014
# 117728         ...           01/07/2020 04:43:00 PM    12/29/2014
# 117741         ...           03/01/2015 11:05:00 AM    01/31/2004
# 117742         ...           08/05/2016 09:50:00 AM    01/31/2004
# 117742         ...           03/01/2015 11:05:00 AM    01/31/2004
#
#            outcome_type outcome_subtype animal_type_outcomes sex_upon_outcome  \
# 8              Transfer         Partner                  Cat    Intact Female
# 9              Adoption             NaN                  Cat    Neutered Male
# 15             Adoption          Foster                  Cat    Neutered Male
# 21             Adoption             NaN                  Dog    Spayed Female
# 21             Adoption             NaN                  Dog    Spayed Female
# 29             Adoption             NaN                  Cat    Spayed Female
# 32      Return to Owner             NaN                  Dog    Intact Female
# 32             Adoption             NaN                  Dog    Spayed Female
# 41      Return to Owner             NaN                  Dog    Spayed Female
# 41      Return to Owner             NaN                  Dog    Spayed Female
# 41      Return to Owner             NaN                  Dog    Spayed Female
# 65             Adoption             NaN                  Dog    Spayed Female
# 65      Return to Owner             NaN                  Dog    Intact Female
# 71             Adoption             NaN                  Dog    Spayed Female
# 73             Adoption             NaN                  Dog    Neutered Male
# 73      Return to Owner             NaN                  Dog      Intact Male
# 74      Return to Owner             NaN                  Dog      Intact Male
# 78      Return to Owner             NaN                  Dog    Neutered Male
# 96             Transfer             Snr                  Cat    Spayed Female
# 100     Return to Owner             NaN                  Dog    Spayed Female
# 100            Adoption             NaN                  Dog    Spayed Female
# 112     Return to Owner             NaN                  Dog    Intact Female
# 118            Adoption          Foster                  Cat    Neutered Male
# 128            Adoption             NaN                  Dog    Neutered Male
# 128            Adoption             NaN                  Dog    Neutered Male
# 140     Return to Owner             NaN                  Dog    Spayed Female
# 147            Adoption             NaN                  Dog    Neutered Male
# 154            Adoption             NaN                  Dog    Spayed Female
# 160            Adoption             NaN                  Dog    Spayed Female
# 160            Adoption             NaN                  Dog    Spayed Female
# ...                 ...             ...                  ...              ...
# 117598         Adoption          Foster                  Dog    Neutered Male
# 117600         Adoption             NaN                  Dog    Neutered Male
# 117614         Adoption          Foster                  Cat    Neutered Male
# 117639         Adoption             NaN                  Dog    Neutered Male
# 19                          1501 S Fm 973 in Austin (TX)            Stray
# 20                         1801 Westridge in Austin (TX)            Stray
# 21                                           Austin (TX)  Owner Surrender
# 21                                           Austin (TX)  Owner Surrender
# 21                                           Austin (TX)  Owner Surrender
# 22                        7900 Rm 1826 Rd in Travis (TX)         Wildlife
# 23               7500 South Interstate 35 in Austin (TX)            Stray
# 24                           2307 Ventura in Austin (TX)            Stray
# 25                          3737 Keats Dr in Austin (TX)            Stray
# 26      East Pleasant Valley And Stassney in Austin (TX)            Stray
# 27                       4100 Westbank Dr in Austin (TX)         Wildlife
# ...                                                  ...              ...
# 117694         Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694         Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694         Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694         Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117694         Oak Springs Dr & Gunter St in Austin (TX)            Stray
# 117703                 8209 Bluff Springs in Travis (TX)    Public Assist
# 117703                 8209 Bluff Springs in Travis (TX)    Public Assist
# 117703                 8209 Bluff Springs in Travis (TX)    Public Assist
# 117705                 8209 Bluss Springs in Austin (TX)            Stray
# 117705                 8209 Bluss Springs in Austin (TX)            Stray
# 117705                 8209 Bluss Springs in Austin (TX)            Stray
# 117707  Night Star Drive And Warrior Lane in Travis (TX)            Stray
# 117708                                       Austin (TX)    Public Assist
# 117708                                       Austin (TX)    Public Assist
# 117708                                       Austin (TX)    Public Assist
# 117709  Night Star Drive And Warrior Lane in Travis (TX)            Stray
# 117714                                       Austin (TX)    Public Assist
# 117715                                       Austin (TX)    Public Assist
# 117715                                       Austin (TX)    Public Assist
# 117715                                       Austin (TX)    Public Assist
# 117723                              Outside Jurisdiction            Stray
# 117726      2300 West Ben White Boulevard in Austin (TX)            Stray
# 117728                      8712 Manor Rd in Travis (TX)            Stray
# 117740             612 Great Britain Blvd in Austin (TX)         Wildlife
# 117741                                       Austin (TX)  Owner Surrender
# 117741                                       Austin (TX)  Owner Surrender
# 117742                                       Austin (TX)  Owner Surrender
# 117742                                       Austin (TX)  Owner Surrender
# 117745                                       Austin (TX)  Owner Surrender
# 117745                                       Austin (TX)  Owner Surrender
#
#        intake_condition animal_type_intakes sex_upon_intake age_upon_intake  \
# 2                Normal                 Dog     Intact Male       11 months
# 3                  Sick                 Cat   Intact Female         4 weeks
# 4                Normal                 Dog   Neutered Male         4 years
# 5                Normal                 Dog   Neutered Male         2 years
# 6                Normal                 Dog   Neutered Male         6 years
# 7                Normal                 Dog     Intact Male         2 years
# 8               Injured                 Cat   Intact Female         4 weeks
# 9                Normal                 Cat   Neutered Male        5 months
# 9                Normal                 Cat   Neutered Male        5 months
# 10               Normal                 Dog     Intact Male         2 years
# 11               Normal                 Dog   Intact Female        5 months
# 12               Normal                 Dog   Intact Female         2 years
# 13               Normal                 Cat   Intact Female         4 years
# 14              Injured                 Cat   Intact Female         2 years
# 15               Normal                 Cat   Neutered Male        14 years
# 15               Normal                 Cat   Neutered Male        14 years
# 16               Normal                 Cat   Intact Female         1 month
# 17               Normal                 Cat   Intact Female         4 weeks
# 18               Normal                 Cat   Intact Female         1 month
# 19               Normal                 Dog   Intact Female        2 months
# 20               Normal                 Dog   Spayed Female        18 years
# 21               Normal                 Dog   Spayed Female         2 years
# 21               Normal                 Dog   Spayed Female         2 years
# 21               Normal                 Dog   Spayed Female         2 years
# 22               Normal               Other         Unknown         2 years
# 23               Normal                 Dog   Intact Female        5 months
# 24               Normal                 Cat   Intact Female         2 years
# 25               Normal                 Dog   Intact Female        5 months
# 26               Normal                 Dog     Intact Male        4 months
# 27               Normal               Other         Unknown          1 year
# ...                 ...                 ...             ...             ...
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117694           Normal                 Dog   Spayed Female        11 years
# 117703           Normal                 Dog     Intact Male         2 years
# 117703           Normal                 Dog     Intact Male         2 years
# 117703           Normal                 Dog     Intact Male         2 years
# 117705           Normal                 Dog     Intact Male         4 years
# 117705           Normal                 Dog     Intact Male         4 years
# 117705           Normal                 Dog     Intact Male         4 years
# 117707           Normal                 Dog   Intact Female         1 weeks
# 117708           Normal                 Dog     Intact Male         2 years
# 117708           Normal                 Dog     Intact Male         2 years
# 117708           Normal                 Dog     Intact Male         2 years
# 117709           Normal                 Dog     Intact Male         3 weeks
# 117714           Normal                 Dog   Neutered Male         3 years
# 117715           Normal                 Dog     Intact Male         6 years
# 117715           Normal                 Dog     Intact Male         6 years
# 117715           Normal                 Dog     Intact Male         6 years
# 117723          Nursing                 Dog   Intact Female         4 weeks
# 117726           Normal                 Dog     Intact Male         5 years
# 117728           Normal                 Dog   Neutered Male         5 years
# 117740             Sick               Other         Unknown          1 year
# 117741           Normal                 Cat   Spayed Female        11 years
# 117741           Normal                 Cat   Spayed Female        11 years
# 117742           Normal                 Cat   Spayed Female        16 years
# 117742           Normal                 Cat   Spayed Female        16 years
# 117745           Normal                 Cat   Spayed Female        11 years
# 117745           Normal                 Cat   Spayed Female        11 years
#
#                ...               monthyear_outcomes date_of_birth  \
# 2              ...           04/21/2016 05:17:00 PM    04/17/2015
# 3              ...           10/21/2013 11:39:00 AM    09/21/2013
# 4              ...           07/02/2014 02:16:00 PM    06/29/2010
# 5              ...           02/21/2017 05:44:00 PM    02/18/2015
# 6              ...           04/18/2019 01:45:00 PM    06/03/2012
# 7              ...           08/04/2015 06:17:00 PM    07/28/2013
# 8              ...           06/11/2018 12:00:00 AM    05/10/2018
# 9              ...           08/13/2016 12:27:00 PM    02/22/2016
# 9              ...           07/29/2016 07:00:00 PM    02/22/2016
# 10             ...           10/15/2017 06:30:00 PM    10/11/2015
# 11             ...           11/28/2015 05:31:00 PM    01/11/2015
# 12             ...           05/28/2015 11:24:00 AM    02/04/2013
# 13             ...           03/13/2019 05:36:00 PM    03/06/2015
# 14             ...           02/04/2017 10:48:00 AM    02/04/2015
# 15             ...           01/26/2014 04:24:00 PM    06/24/1999
# 15             ...           10/29/2013 11:07:00 AM    06/24/1999
# 16             ...           11/29/2018 07:22:00 PM    09/22/2018
# 17             ...           08/19/2015 05:59:00 PM    06/15/2015
# 18             ...           10/12/2016 06:32:00 PM    08/08/2016
# 19             ...           03/08/2015 06:55:00 PM    12/20/2014
# 20             ...           09/07/2015 11:40:00 AM    02/07/1997
# 21             ...           07/29/2017 01:38:00 PM    02/09/2017
# 21             ...           08/06/2018 05:16:00 PM    02/09/2017
# 21             ...           08/15/2019 01:42:00 PM    02/09/2017
# 22             ...           12/26/2019 08:38:00 AM    12/24/2017
# 23             ...           04/13/2018 04:12:00 PM    10/10/2017
# 24             ...           09/08/2015 08:03:00 PM    07/20/2013
# 25             ...           06/29/2014 05:26:00 PM    12/25/2013
# 26             ...           05/15/2017 01:25:00 PM    12/15/2016
# 27             ...           03/24/2016 05:17:00 PM    03/24/2015
# ...            ...                              ...           ...
# 117694         ...           12/13/2015 06:28:00 PM    11/10/2008
# 117694         ...           01/15/2018 12:52:00 PM    11/10/2008
# 117694         ...           07/07/2015 05:40:00 PM    11/10/2008
# 117694         ...           01/02/2016 06:35:00 PM    11/10/2008
# 117694         ...           06/08/2020 01:22:00 PM    11/10/2008
# 117703         ...           05/07/2018 06:23:00 PM    03/04/2014
# 117703         ...           12/07/2016 03:13:00 PM    03/04/2014
# 117703         ...           08/09/2016 04:49:00 PM    03/04/2014
# 117705         ...           05/07/2018 06:23:00 PM    03/04/2014
# 117705         ...           12/07/2016 03:13:00 PM    03/04/2014
# 117705         ...           08/09/2016 04:49:00 PM    03/04/2014
# 117707         ...           05/28/2020 01:53:00 PM    02/23/2020
# 117708         ...           05/07/2018 06:23:00 PM    03/04/2014
# 117708         ...           12/07/2016 03:13:00 PM    03/04/2014
# 117708         ...           08/09/2016 04:49:00 PM    03/04/2014
# 117709         ...           04/27/2020 11:39:00 AM    02/09/2020
# 117714         ...           02/05/2020 05:25:00 PM    01/27/2017
# 117715         ...           05/07/2018 06:23:00 PM    03/04/2014
# 117715         ...           12/07/2016 03:13:00 PM    03/04/2014
# 117715         ...           08/09/2016 04:49:00 PM    03/04/2014
# 117723         ...           11/18/2019 07:37:00 PM    10/14/2019
# 117726         ...           01/07/2020 04:43:00 PM    12/29/2014
# 117728         ...           01/07/2020 04:43:00 PM    12/29/2014
# 117740         ...           06/09/2020 01:18:00 PM    06/09/2019
# 117741         ...           08/05/2016 09:50:00 AM    01/31/2004
# 117741         ...           03/01/2015 11:05:00 AM    01/31/2004
# 117742         ...           08/05/2016 09:50:00 AM    01/31/2004
# 117742         ...           03/01/2015 11:05:00 AM    01/31/2004
# 117745         ...           08/05/2016 09:50:00 AM    01/31/2004
# 117745         ...           03/01/2015 11:05:00 AM    01/31/2004
#
#            outcome_type outcome_subtype animal_type_outcomes sex_upon_outcome  \
# 2       Return to Owner             NaN                  Dog    Neutered Male
# 3              Transfer         Partner                  Cat    Intact Female
# 4       Return to Owner             NaN                  Dog    Neutered Male
# 5       Return to Owner             NaN                  Dog    Neutered Male
# 6       Return to Owner             NaN                  Dog    Neutered Male
# 7       Return to Owner             NaN                  Dog    Neutered Male
# 8              Transfer         Partner                  Cat    Intact Female
# 9              Transfer         Partner                  Cat    Neutered Male
# 9              Adoption             NaN                  Cat    Neutered Male
# 10             Adoption             NaN                  Dog    Neutered Male
# 11             Adoption             NaN                  Dog    Spayed Female
# 12             Adoption          Foster                  Dog    Spayed Female
# 13      Return to Owner             NaN                  Cat    Intact Female
# 117694     Blue Merle/White -1638 days +08:37:00
# 117694     Blue Merle/White  -874 days +03:01:00
# 117694     Blue Merle/White -1797 days +07:49:00
# 117694     Blue Merle/White -1618 days +08:44:00
# 117694     Blue Merle/White      1 days 03:31:00
# 117703  Black Brindle/White    641 days 03:25:00
# 117703  Black Brindle/White    125 days 00:15:00
# 117703  Black Brindle/White      5 days 01:51:00
# 117705  Black Brindle/White     11 days 04:35:00
# 117705  Black Brindle/White  -505 days +01:25:00
# 117705  Black Brindle/White  -625 days +03:01:00
# 117707          Brown Merle     86 days 18:53:00
# 117708  Black Brindle/White    526 days 02:41:00
# 117708  Black Brindle/White      9 days 23:31:00
# 117708  Black Brindle/White  -110 days +01:07:00
# 117709                Brown     55 days 16:39:00
# 117714          Brown/Black  -124 days +00:59:00
# 117715  Black Brindle/White  -763 days +03:36:00
# 117715  Black Brindle/White -1279 days +00:26:00
# 117715  Black Brindle/White -1399 days +02:02:00
# 117723                  Tan      4 days 01:37:00
# 117726          Brown/Black      8 days 22:58:00
# 117728          Brown/Black  -154 days +17:08:00
# 117740                Black      0 days 00:47:00
# 117741    Brown Tabby/White    466 days 22:11:00
# 117741    Brown Tabby/White   -57 days +23:26:00
# 117742    Brown Tabby/White -1405 days +22:56:00
# 117742    Brown Tabby/White -1927 days +00:11:00
# 117745    Brown Tabby/White    551 days 16:19:00
# 117745    Brown Tabby/White     28 days 17:34:00
#
# [152184 rows x 24 columns]

# %% [markdown]
# ## 5. Pandas Practice
#
# ### Introduction

# %%
# find and import the World Cup data held in data/ folder
# !ls data/
# Out:
# WorldCupMatches.csv ds_chars.csv        heart.csv           states.csv

# %%
wc = pd.read_csv('data/WorldCupMatches.csv')

# %%
wc.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %%
wc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# ### Practice Questions <a id="practice"></a>

# %% [markdown]
# 1. Subset the DataFrame to only non-null rows.

# %%
#Your code here.
wc = wc.dropna()

# %%
wc.columns = wc.columns.map(lambda x: x.lower().replace(' ','_'))

# %%
wc.head()
# Out:
#    year              datetime    stage         stadium         city  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   home_team_name  home_team_goals  away_team_goals away_team_name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   win_conditions  attendance  half-time_home_goals  half-time_away_goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   referee               assistant_1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   assistant_2  roundid  matchid home_team_initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   away_team_initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# 2. How many of the matches were in Montevideo?

# %%
#Your code here.
wc['city'] = wc['city'].map(lambda x: x.strip())

# %%
len(wc.loc[wc['city'] == 'Montevideo'])
# Out:
# 18

# %% [markdown]
# 2. b If you haven't already, investigate why this code returns zero:
#
# ```python
# print(len(df[df.City=="Montevideo"]))
# ```

# %%
#Your code here.

# %% [markdown]
# 3. How many matches did USA play in 2014?
#
# Hint: they could have been home or away.
#
# You can combine conditions like this:
# ```python
# # Returns rows where either condition is true
# df[(condition1) | (condition2)]
#
# # Returns rows where both conditions are true
# df[(condition1) & (condition2)]
# ```

# %%
#Your code here.
len(wc.loc[(wc.year == 1930)&((wc.home_team_name == 'USA')|(wc.away_team_name == 'USA'))])
# Out:
# 3

# %% [markdown]
# 4. How many teams played in 1986?

# %%
import numpy as np

# %%
#Your code here.
hometeam_1986 = wc.loc[wc.year == 1986]['home_team_name'].unique()
awayteam_1986 = wc.loc[wc.year == 1986]['away_team_name'].unique()
len(np.unique(np.concatenate([hometeam_1986,awayteam_1986])))
# Out:
# 24

# %% [markdown]
# 5. How many matches were there with 5 or more total goals?

# %%
wc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 850 entries, 0 to 851
# Data columns (total 20 columns):
# year                    850 non-null int64
# datetime                850 non-null object
# stage                   850 non-null object
# stadium                 850 non-null object
# city                    850 non-null object
# home_team_name          850 non-null object
# home_team_goals         850 non-null int64
# away_team_goals         850 non-null int64
# away_team_name          850 non-null object
# win_conditions          850 non-null object
# attendance              850 non-null float64
# half-time_home_goals    850 non-null int64
# half-time_away_goals    850 non-null int64
# referee                 850 non-null object
# assistant_1             850 non-null object
# assistant_2             850 non-null object
# roundid                 850 non-null int64
# matchid                 850 non-null int64
# home_team_initials      850 non-null object
# away_team_initials      850 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 179.5+ KB

# %%
#Your code here.
len(wc.loc[(wc['home_team_goals']+wc['away_team_goals']>=5)])
# Out:
# 147

# %% [markdown]
# 6. Come up with and answer, two other questions you could answer by filtering or subsetting this DataFrame.

# %%
wc.head(10)
# Out:
#    year              datetime    stage             stadium        city  \
# 0  1930  13 Jul 1930 - 15:00   Group 1             Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4      Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3             Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1      Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1      Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 7  1930  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 8  1930  18 Jul 1930 - 14:30   Group 3  Estadio Centenario  Montevideo
# 9  1930  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
#
#   home_team_name  home_team_goals  away_team_goals away_team_name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
# 7            USA                3                0       Paraguay
# 8        Uruguay                1                0           Peru
# 9          Chile                1                0         France
#
#   win_conditions  attendance  half-time_home_goals  half-time_away_goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
# 7                    18306.0                     2                     0
# 8                    57735.0                     0                     0
# 9                     2000.0                     0                     0
#
#                     referee               assistant_1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
# 7         MACIAS Jose (ARG)   APHESTEGUY Martin (URU)
# 8       LANGENUS Jean (BEL)       BALWAY Thomas (FRA)
# 9       TEJADA Anibal (URU)    LOMBARDI Domingo (URU)
#
#                   assistant_2  roundid  matchid home_team_initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
# 7         TEJADA Anibal (URU)      201     1097                USA
# 8       CRISTOPHE Henry (BEL)      201     1099                URU
# 9         REGO Gilberto (BRA)      201     1094                CHI
#
#   away_team_initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL
# 7                PAR
# 8                PER
# 9                FRA

# %%
#6a Question: is home_team has advantage to get goals (total home team goal is bigger than away team goal)

# %%
#6a Solution (with code):
print(wc.home_team_goals.sum())
print(wc.away_team_goals.sum())
# Out:
# 1539
# 869

# %%
#6b Question: which year has most goals?

# %%
#6b Solution (with code):
groupby_wc = wc.groupby('year').sum()

# %%
groupby_wc['total_goals'] = groupby_wc.home_team_goals + groupby_wc.away_team_goals

# %%
groupby_wc.loc[groupby_wc['total_goals'] == groupby_wc['total_goals'].max()]
# Out:
#       home_team_goals  away_team_goals  attendance  half-time_home_goals  \
# year
# 2014               95              105   4319243.0                    28
#
#       half-time_away_goals   roundid      matchid  total_goals
# year
# 2014                    46  19963278  23414545796          200
